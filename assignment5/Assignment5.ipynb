# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, dropout_percent=1.0, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here
            #
            weight_init = IsotropicGaussian(mean=0., std=np.sqrt(2.0/(num_out*num_in)))
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
        self.dropout_percent = dropout_percent
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X, do_dropout=False):
        #Save X for later reusal

#         if do_dropout:
#             nes = self.W * (np.random.rand(*self.W.shape) < self.dropout_percent) / self.dropout_percent
#             Y = np.dot(nes, X) +  self.b
#         else:
#             Y = np.dot(self.W, X) +  self.b
            
#         if do_dropout and self.dropout_percent < 1.0:
#             X *= (np.random.rand(*X.shape) < self.dropout_percent) / self.dropout_percent

        fprop_context = dict(X=X)
        
        Y = np.dot(self.W, X) +  self.b
#         if False:
#         if do_dropout:
#             Y *= np.random.binomial([np.ones(Y.shape)],1-self.dropout_percent)[0] * (1.0/(1-self.dropout_percent))

    
        
#         if do_dropout:
#         if False:
#             dropout_percent = 0.5
#             Y *= np.random.binomial([np.ones(Y.shape)],1-dropout_percent)[0] * (1.0/(1-dropout_percent))
        
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        #
        # TODO: fill in gradient computation
        #
        dLdX = np.dot(self.W.T, dLdY)
        return dLdX
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, dropout_percent=1.0, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
        self.dropout_percent = dropout_percent
    
    def fprop(self, X, do_dropout=False):
        Y = np.tanh(X)

        if do_dropout and self.dropout_percent < 1.0:
            Y *= (np.random.rand(*Y.shape) < self.dropout_percent) / self.dropout_percent

        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        dLdX = (dLdY * (1 - Y**2))
        return dLdX

    
class ReLULayer(Layer):
    def __init__(self, dropout_percent=1.0, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
        self.dropout_percent = dropout_percent
    
    def fprop(self, X, do_dropout=False):
        Y = np.maximum(X, 0.0)
                
        if do_dropout and self.dropout_percent < 1.0:
            Y *= (np.random.rand(*Y.shape) < self.dropout_percent) / self.dropout_percent

        fprop_context = dict(Y=Y)
            
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X, do_dropout=False):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X, do_dropout)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y, do_dropout=False):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X, do_dropout)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 1.373673, train error rate 92.666667%
# At iteration 1000, loss 0.053196, train error rate 2.000000%
# At iteration 2000, loss 0.043734, train error rate 1.333333%
# At iteration 3000, loss 0.041226, train error rate 1.333333%
# At iteration 4000, loss 0.040079, train error rate 1.333333%
# At iteration 5000, loss 0.039360, train error rate 1.333333%
# At iteration 6000, loss 0.038813, train error rate 1.333333%
# At iteration 7000, loss 0.038353, train error rate 1.333333%
# At iteration 8000, loss 0.037945, train error rate 1.333333%
# At iteration 9000, loss 0.037574, train error rate 1.333333%
# At iteration 10000, loss 0.037232, train error rate 1.333333%
# At iteration 11000, loss 0.036910, train error rate 1.333333%
# At iteration 12000, loss 0.036601, train error rate 1.333333%
# At iteration 13000, loss 0.036294, train error rate 1.333333%
# At iteration 14000, loss 0.035982, train error rate 1.333333%
# At iteration 15000, loss 0.035654, train error rate 1.333333%
# At iteration 16000, loss 0.035301, train error rate 1.333333%
# At iteration 17000, loss 0.034916, train error rate 1.333333%
# At iteration 18000, loss 0.034495, train error rate 1.333333%
# At iteration 19000, loss 0.034032, train error rate 1.333333%
# At iteration 20000, loss 0.033525, train error rate 1.333333%
# At iteration 21000, loss 0.032972, train error rate 1.333333%
# At iteration 22000, loss 0.032373, train error rate 1.333333%
# At iteration 23000, loss 0.031729, train error rate 1.333333%
# At iteration 24000, loss 0.031044, train error rate 1.333333%
# At iteration 25000, loss 0.030323, train error rate 1.333333%
# At iteration 26000, loss 0.029568, train error rate 1.333333%
# At iteration 27000, loss 0.028778, train error rate 1.333333%
# At iteration 28000, loss 0.027945, train error rate 1.333333%
# At iteration 29000, loss 0.027055, train error rate 1.333333%
# At iteration 30000, loss 0.026089, train error rate 1.333333%
# At iteration 31000, loss 0.025020, train error rate 1.333333%
# At iteration 32000, loss 0.023814, train error rate 1.333333%
# At iteration 33000, loss 0.022428, train error rate 1.333333%
# At iteration 34000, loss 0.020847, train error rate 1.333333%
# At iteration 35000, loss 0.019141, train error rate 0.666667%
# At iteration 36000, loss 0.017445, train error rate 0.666667%
# At iteration 37000, loss 0.015859, train error rate 0.666667%
# At iteration 38000, loss 0.014417, train error rate 0.666667%
# At iteration 39000, loss 0.013121, train error rate 0.666667%
# At iteration 40000, loss 0.011958, train error rate 0.000000%
# At iteration 41000, loss 0.010917, train error rate 0.000000%
# At iteration 42000, loss 0.009985, train error rate 0.000000%
# At iteration 43000, loss 0.009153, train error rate 0.000000%
# At iteration 44000, loss 0.008409, train error rate 0.000000%
# At iteration 45000, loss 0.007745, train error rate 0.000000%
# At iteration 46000, loss 0.007150, train error rate 0.000000%
# At iteration 47000, loss 0.006617, train error rate 0.000000%
# At iteration 48000, loss 0.006137, train error rate 0.000000%
# At iteration 49000, loss 0.005706, train error rate 0.000000%

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy


def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def SGD(net, train_stream, validation_stream, test_stream):
#     beta1 = 0.9
#     beta2 = 0.999
#     epsilon = 1e-8
#     rho = 0.9
#     decay = 0.0001
#     lr = 0.001
#     alpha0 = 1e-1
#     alpha = alpha0
    i=0
    e=0
    
    #initialize momentum variables
    #
    # TODO
    #
    # Hint: you need one valocity matrix for each parameter
    momentum = 0.99
    decay = 0.0005
    alpha0 = 3e-1
    alpha = alpha0
    max_norm = 4

    velocities = [np.zeros(P.shape, dtype=P.dtype) for P in net.parameters]
#     velocities = [np.random.rand(P.shape[0]*P.shape[1]).reshape(P.shape)/100 for P in net.parameters]
#     moment = [np.zeros(P.shape) for P in net.parameters]
#     print velocities, len(net.parameters)
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    train_erros = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = 3
    patience_expansion = 1.5
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
#                 lr *= (1. / (1. + decay * i))
                
                L, O, gradients = net.get_cost_and_gradient(X, Y, True)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_erros.append((i,err_rate))
                if i % 100 == 0:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%, alpha %f" % (i, L, err_rate*100, alpha)
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
#                 for P, V, G, N, M in zip(net.parameters, velocities, gradients, net.parameter_names, moment):
#                     print V.shape, P.shape, G.shape
                    if N=='W':
                        G += - 0.0005 * G
#                         alpha = alpha0 * (1 - i/20000.)
                        pass
                        #
                        # TODO: implement the weight decay addition to gradient
                        #
                        #G += -alf*P
                    
                    #
                    # TODO: set a learning rate
                    #
                    # Hint, use the iteration counter i
                    
                    alpha = alpha0 * 0.9999**(i)
#                     alpha = 0.2
                    #
                    # TODO: set the momentum constant 
                    
                    #
                    # TODO: implement velocity update in momentum
                    #
#                     V = momentum * V - alpha * G
                    
#                     if i % 100 == 0:
#                         print 'G', np.where(np.linalg.norm(G, axis=1) > 0.1)
#                         print 'V', np.where(np.linalg.norm(V,axis=1) > 0.1)
                    row_norm = np.linalg.norm(G, axis=1)
                    max_norm = 0.1
                    mask = np.where(row_norm > max_norm)
                    row_norm[mask] = row_norm[mask]/max_norm
                    G[mask] = G[mask]/row_norm[mask].reshape((-1,1))
                    
                    # V[...] = TODO
                    V = momentum * V - alpha * G
                    P += V
#                     P += - alpha * G
#                         continue
#                     V = 0.9 * V + (1. - 0.9) * np.square(G)
#                     P += - alpha * G / (np.sqrt(V) + epsilon)
                    
                    #
                    # TODO: set a more sensible learning rule here,
                    # using your learning rate schedule and momentum
                    #
                    #!!!!! Need to modify the actual parameter here!
                    #print i, 'grad', len(G), len(P), len(G[0]), len(P[0])
#                     M = beta1 * M + (1 - beta1) * G
#                     V = beta2 * V + (1 - beta2) * G**2
#                     M2 = M/(1 - beta1**i)
#                     V2 = V/(1 - beta2**i)
#                     P = P - alpha * M2 / (np.sqrt(V2) + epsilon)
                    
#                     V = epsilon * V - alpha * G
#                     P += V
#                     P += - alpha * G
#                     if i < 2000:
#                         P += - alpha * G
#                         continue
    
#                     V = rho * V + (1. - rho) * np.square(G)
#                     print - alpha * G / (np.sqrt(V) + epsilon) 
#                     P += - alpha * G / (np.sqrt(V) + epsilon)
        
#                     M = (beta1 * M) + (1. - beta1) * G
#                     V = (beta2 * V) + (1. - beta2) * np.square(G)
#                     P = P - lr * M / (np.sqrt(V) + epsilon)
            
            
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                e, val_error_rate, number_of_epochs)
            
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        
        subplot(2,1,1)
        train_loss = np.array(train_loss)
        semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
        legend()
        
        subplot(2,1,2)
        train_erros = np.array(train_erros)
        plot(train_erros[:,0], train_erros[:,1], label='batch train error rate')
        validation_errors = np.array(validation_errors)
        plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
        ylim(0,0.2)
        legend()

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: pick a network architecture here. The one below is just 
# softmax regression
#

net = FeedForwardNet([
        AffineLayer(784,600),
        ReLULayer(),
        AffineLayer(600,200),
        ReLULayer(),
        AffineLayer(200,10),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 0.841693, batch error rate 31.000000%, alpha 0.297045
# At minibatch 200, batch loss 0.636310, batch error rate 21.000000%, alpha 0.294089
# At minibatch 300, batch loss 0.323156, batch error rate 11.000000%, alpha 0.291162
# At minibatch 400, batch loss 0.470165, batch error rate 15.000000%, alpha 0.288265
# At minibatch 500, batch loss 0.187942, batch error rate 4.000000%, alpha 0.285397
# After epoch 1: valid_err_rate: 0.078900% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.326579, batch error rate 10.000000%, alpha 0.282557
# At minibatch 700, batch loss 0.122720, batch error rate 5.000000%, alpha 0.279745
# At minibatch 800, batch loss 0.408577, batch error rate 15.000000%, alpha 0.276961
# At minibatch 900, batch loss 0.216251, batch error rate 6.000000%, alpha 0.274206
# At minibatch 1000, batch loss 0.240067, batch error rate 7.000000%, alpha 0.271477
# After epoch 2: valid_err_rate: 0.044200% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.201428, batch error rate 7.000000%, alpha 0.268776
# At minibatch 1200, batch loss 0.117326, batch error rate 3.000000%, alpha 0.266101
# At minibatch 1300, batch loss 0.139206, batch error rate 6.000000%, alpha 0.263453
# At minibatch 1400, batch loss 0.086682, batch error rate 2.000000%, alpha 0.260832
# At minibatch 1500, batch loss 0.152968, batch error rate 4.000000%, alpha 0.258236
# After epoch 3: valid_err_rate: 0.035800% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.129923, batch error rate 4.000000%, alpha 0.255667
# At minibatch 1700, batch loss 0.047703, batch error rate 2.000000%, alpha 0.253123
# At minibatch 1800, batch loss 0.106076, batch error rate 3.000000%, alpha 0.250604
# At minibatch 1900, batch loss 0.076428, batch error rate 2.000000%, alpha 0.248110
# At minibatch 2000, batch loss 0.092423, batch error rate 4.000000%, alpha 0.245641
# After epoch 4: valid_err_rate: 0.029200% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.063822, batch error rate 1.000000%, alpha 0.243197
# At minibatch 2200, batch loss 0.072807, batch error rate 3.000000%, alpha 0.240777
# At minibatch 2300, batch loss 0.165558, batch error rate 5.000000%, alpha 0.238381
# At minibatch 2400, batch loss 0.051526, batch error rate 2.000000%, alpha 0.236009
# At minibatch 2500, batch loss 0.275520, batch error rate 7.000000%, alpha 0.233661
# After epoch 5: valid_err_rate: 0.027700% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.105289, batch error rate 2.000000%, alpha 0.231336
# At minibatch 2700, batch loss 0.041785, batch error rate 1.000000%, alpha 0.229034
# At minibatch 2800, batch loss 0.039833, batch error rate 2.000000%, alpha 0.226755
# At minibatch 2900, batch loss 0.096873, batch error rate 2.000000%, alpha 0.224498
# At minibatch 3000, batch loss 0.023061, batch error rate 1.000000%, alpha 0.222264
# After epoch 6: valid_err_rate: 0.022700% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.092674, batch error rate 4.000000%, alpha 0.220053
# At minibatch 3200, batch loss 0.058051, batch error rate 2.000000%, alpha 0.217863
# At minibatch 3300, batch loss 0.037662, batch error rate 1.000000%, alpha 0.215695
# At minibatch 3400, batch loss 0.018711, batch error rate 1.000000%, alpha 0.213549
# At minibatch 3500, batch loss 0.089859, batch error rate 3.000000%, alpha 0.211424
# After epoch 7: valid_err_rate: 0.028400% currently going ot do 10 epochs
# At minibatch 3600, batch loss 0.027372, batch error rate 1.000000%, alpha 0.209320
# At minibatch 3700, batch loss 0.022698, batch error rate 1.000000%, alpha 0.207237
# At minibatch 3800, batch loss 0.093245, batch error rate 1.000000%, alpha 0.205175
# At minibatch 3900, batch loss 0.085784, batch error rate 2.000000%, alpha 0.203133
# At minibatch 4000, batch loss 0.099544, batch error rate 3.000000%, alpha 0.201112
# After epoch 8: valid_err_rate: 0.024300% currently going ot do 10 epochs
# At minibatch 4100, batch loss 0.013967, batch error rate 0.000000%, alpha 0.199111
# At minibatch 4200, batch loss 0.021474, batch error rate 1.000000%, alpha 0.197130
# At minibatch 4300, batch loss 0.034465, batch error rate 1.000000%, alpha 0.195168
# At minibatch 4400, batch loss 0.015356, batch error rate 1.000000%, alpha 0.193226
# At minibatch 4500, batch loss 0.053128, batch error rate 1.000000%, alpha 0.191303
# After epoch 9: valid_err_rate: 0.023600% currently going ot do 10 epochs
# At minibatch 4600, batch loss 0.121861, batch error rate 3.000000%, alpha 0.189400
# At minibatch 4700, batch loss 0.029827, batch error rate 1.000000%, alpha 0.187515
# At minibatch 4800, batch loss 0.056953, batch error rate 3.000000%, alpha 0.185649
# At minibatch 4900, batch loss 0.031054, batch error rate 2.000000%, alpha 0.183802
# At minibatch 5000, batch loss 0.047091, batch error rate 1.000000%, alpha 0.181973
# After epoch 10: valid_err_rate: 0.020600% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.018526, batch error rate 1.000000%, alpha 0.180162
# At minibatch 5200, batch loss 0.006732, batch error rate 0.000000%, alpha 0.178369
# At minibatch 5300, batch loss 0.023495, batch error rate 2.000000%, alpha 0.176594
# At minibatch 5400, batch loss 0.006229, batch error rate 0.000000%, alpha 0.174837
# At minibatch 5500, batch loss 0.008189, batch error rate 0.000000%, alpha 0.173097
# After epoch 11: valid_err_rate: 0.019400% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.011784, batch error rate 0.000000%, alpha 0.171375
# At minibatch 5700, batch loss 0.009205, batch error rate 0.000000%, alpha 0.169670
# At minibatch 5800, batch loss 0.005994, batch error rate 0.000000%, alpha 0.167981
# At minibatch 5900, batch loss 0.004819, batch error rate 0.000000%, alpha 0.166310
# At minibatch 6000, batch loss 0.008601, batch error rate 0.000000%, alpha 0.164655
# After epoch 12: valid_err_rate: 0.018900% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.008339, batch error rate 0.000000%, alpha 0.163017
# At minibatch 6200, batch loss 0.018339, batch error rate 0.000000%, alpha 0.161394
# At minibatch 6300, batch loss 0.016571, batch error rate 1.000000%, alpha 0.159788
# At minibatch 6400, batch loss 0.037564, batch error rate 1.000000%, alpha 0.158198
# At minibatch 6500, batch loss 0.003109, batch error rate 0.000000%, alpha 0.156624
# After epoch 13: valid_err_rate: 0.020000% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.032674, batch error rate 1.000000%, alpha 0.155066
# At minibatch 6700, batch loss 0.004701, batch error rate 0.000000%, alpha 0.153523
# At minibatch 6800, batch loss 0.004132, batch error rate 0.000000%, alpha 0.151995
# At minibatch 6900, batch loss 0.008690, batch error rate 0.000000%, alpha 0.150483
# At minibatch 7000, batch loss 0.008436, batch error rate 0.000000%, alpha 0.148985
# After epoch 14: valid_err_rate: 0.019300% currently going ot do 19 epochs
# At minibatch 7100, batch loss 0.005703, batch error rate 0.000000%, alpha 0.147503
# At minibatch 7200, batch loss 0.001636, batch error rate 0.000000%, alpha 0.146035
# At minibatch 7300, batch loss 0.001652, batch error rate 0.000000%, alpha 0.144582
# At minibatch 7400, batch loss 0.009001, batch error rate 0.000000%, alpha 0.143143
# At minibatch 7500, batch loss 0.105458, batch error rate 2.000000%, alpha 0.141719
# After epoch 15: valid_err_rate: 0.019600% currently going ot do 19 epochs
# At minibatch 7600, batch loss 0.001241, batch error rate 0.000000%, alpha 0.140309
# At minibatch 7700, batch loss 0.001603, batch error rate 0.000000%, alpha 0.138912
# At minibatch 7800, batch loss 0.020466, batch error rate 1.000000%, alpha 0.137530
# At minibatch 7900, batch loss 0.023274, batch error rate 2.000000%, alpha 0.136162
# At minibatch 8000, batch loss 0.002370, batch error rate 0.000000%, alpha 0.134807
# After epoch 16: valid_err_rate: 0.018000% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.010712, batch error rate 0.000000%, alpha 0.133465
# At minibatch 8200, batch loss 0.000690, batch error rate 0.000000%, alpha 0.132137
# At minibatch 8300, batch loss 0.000733, batch error rate 0.000000%, alpha 0.130822
# At minibatch 8400, batch loss 0.000679, batch error rate 0.000000%, alpha 0.129521
# At minibatch 8500, batch loss 0.005061, batch error rate 0.000000%, alpha 0.128232
# After epoch 17: valid_err_rate: 0.019300% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.006762, batch error rate 0.000000%, alpha 0.126956
# At minibatch 8700, batch loss 0.004966, batch error rate 0.000000%, alpha 0.125693
# At minibatch 8800, batch loss 0.015526, batch error rate 1.000000%, alpha 0.124442
# At minibatch 8900, batch loss 0.001356, batch error rate 0.000000%, alpha 0.123204
# At minibatch 9000, batch loss 0.001908, batch error rate 0.000000%, alpha 0.121978
# After epoch 18: valid_err_rate: 0.016800% currently going ot do 28 epochs
# At minibatch 9100, batch loss 0.004648, batch error rate 0.000000%, alpha 0.120764
# At minibatch 9200, batch loss 0.002310, batch error rate 0.000000%, alpha 0.119562
# At minibatch 9300, batch loss 0.000501, batch error rate 0.000000%, alpha 0.118372
# At minibatch 9400, batch loss 0.002352, batch error rate 0.000000%, alpha 0.117195
# At minibatch 9500, batch loss 0.013590, batch error rate 1.000000%, alpha 0.116028
# After epoch 19: valid_err_rate: 0.017400% currently going ot do 28 epochs
# At minibatch 9600, batch loss 0.001619, batch error rate 0.000000%, alpha 0.114874
# At minibatch 9700, batch loss 0.000857, batch error rate 0.000000%, alpha 0.113731
# At minibatch 9800, batch loss 0.002442, batch error rate 0.000000%, alpha 0.112599
# At minibatch 9900, batch loss 0.000911, batch error rate 0.000000%, alpha 0.111479
# At minibatch 10000, batch loss 0.000791, batch error rate 0.000000%, alpha 0.110369
# After epoch 20: valid_err_rate: 0.017600% currently going ot do 28 epochs
# At minibatch 10100, batch loss 0.001780, batch error rate 0.000000%, alpha 0.109271
# At minibatch 10200, batch loss 0.000248, batch error rate 0.000000%, alpha 0.108184
# At minibatch 10300, batch loss 0.001550, batch error rate 0.000000%, alpha 0.107107
# At minibatch 10400, batch loss 0.001034, batch error rate 0.000000%, alpha 0.106041
# At minibatch 10500, batch loss 0.000996, batch error rate 0.000000%, alpha 0.104986
# After epoch 21: valid_err_rate: 0.017500% currently going ot do 28 epochs
# At minibatch 10600, batch loss 0.002177, batch error rate 0.000000%, alpha 0.103942
# At minibatch 10700, batch loss 0.001236, batch error rate 0.000000%, alpha 0.102907
# At minibatch 10800, batch loss 0.002052, batch error rate 0.000000%, alpha 0.101883
# At minibatch 10900, batch loss 0.008217, batch error rate 1.000000%, alpha 0.100870
# At minibatch 11000, batch loss 0.000806, batch error rate 0.000000%, alpha 0.099866
# After epoch 22: valid_err_rate: 0.017800% currently going ot do 28 epochs
# At minibatch 11100, batch loss 0.003278, batch error rate 0.000000%, alpha 0.098872
# At minibatch 11200, batch loss 0.001988, batch error rate 0.000000%, alpha 0.097888
# At minibatch 11300, batch loss 0.001346, batch error rate 0.000000%, alpha 0.096914
# At minibatch 11400, batch loss 0.000469, batch error rate 0.000000%, alpha 0.095950
# At minibatch 11500, batch loss 0.002196, batch error rate 0.000000%, alpha 0.094995
# After epoch 23: valid_err_rate: 0.017200% currently going ot do 28 epochs
# At minibatch 11600, batch loss 0.000370, batch error rate 0.000000%, alpha 0.094050
# At minibatch 11700, batch loss 0.001996, batch error rate 0.000000%, alpha 0.093114
# At minibatch 11800, batch loss 0.002947, batch error rate 0.000000%, alpha 0.092187
# At minibatch 11900, batch loss 0.000235, batch error rate 0.000000%, alpha 0.091270
# At minibatch 12000, batch loss 0.000203, batch error rate 0.000000%, alpha 0.090362
# After epoch 24: valid_err_rate: 0.017800% currently going ot do 28 epochs
# At minibatch 12100, batch loss 0.000878, batch error rate 0.000000%, alpha 0.089463
# At minibatch 12200, batch loss 0.000813, batch error rate 0.000000%, alpha 0.088573
# At minibatch 12300, batch loss 0.000450, batch error rate 0.000000%, alpha 0.087691
# At minibatch 12400, batch loss 0.001225, batch error rate 0.000000%, alpha 0.086819
# At minibatch 12500, batch loss 0.002182, batch error rate 0.000000%, alpha 0.085955
# After epoch 25: valid_err_rate: 0.018100% currently going ot do 28 epochs
# At minibatch 12600, batch loss 0.001509, batch error rate 0.000000%, alpha 0.085099
# At minibatch 12700, batch loss 0.001615, batch error rate 0.000000%, alpha 0.084253
# At minibatch 12800, batch loss 0.000474, batch error rate 0.000000%, alpha 0.083414
# At minibatch 12900, batch loss 0.002621, batch error rate 0.000000%, alpha 0.082584
# At minibatch 13000, batch loss 0.001937, batch error rate 0.000000%, alpha 0.081762
# After epoch 26: valid_err_rate: 0.016900% currently going ot do 28 epochs
# At minibatch 13100, batch loss 0.000913, batch error rate 0.000000%, alpha 0.080949
# At minibatch 13200, batch loss 0.000441, batch error rate 0.000000%, alpha 0.080143
# At minibatch 13300, batch loss 0.000384, batch error rate 0.000000%, alpha 0.079346
# At minibatch 13400, batch loss 0.000171, batch error rate 0.000000%, alpha 0.078556
# At minibatch 13500, batch loss 0.000697, batch error rate 0.000000%, alpha 0.077775
# After epoch 27: valid_err_rate: 0.017000% currently going ot do 28 epochs
# At minibatch 13600, batch loss 0.000698, batch error rate 0.000000%, alpha 0.077001
# At minibatch 13700, batch loss 0.000975, batch error rate 0.000000%, alpha 0.076234
# At minibatch 13800, batch loss 0.000872, batch error rate 0.000000%, alpha 0.075476
# At minibatch 13900, batch loss 0.003838, batch error rate 0.000000%, alpha 0.074725
# At minibatch 14000, batch loss 0.001004, batch error rate 0.000000%, alpha 0.073981
# After epoch 28: valid_err_rate: 0.017200% currently going ot do 28 epochs
# Test error rate: 0.017300

# %%
epoch = 28, 0.0172
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0173

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.

# %%
net = FeedForwardNet([
        AffineLayer(784,800, dropout_percent=1),
        ReLULayer(dropout_percent=0.77),
#         TanhLayer(),
        AffineLayer(800,600, dropout_percent=1),
        ReLULayer(dropout_percent=0.6),
#         TanhLayer(),
        AffineLayer(600,10, dropout_percent=1),
#         ReLULayer(),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 1.020404, batch error rate 40.000000%, alpha 0.297045
# At minibatch 200, batch loss 0.362937, batch error rate 14.000000%, alpha 0.294089
# At minibatch 300, batch loss 0.351410, batch error rate 9.000000%, alpha 0.291162
# At minibatch 400, batch loss 0.375008, batch error rate 12.000000%, alpha 0.288265
# At minibatch 500, batch loss 0.334091, batch error rate 14.000000%, alpha 0.285397
# After epoch 1: valid_err_rate: 0.085500% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.204162, batch error rate 4.000000%, alpha 0.282557
# At minibatch 700, batch loss 0.253866, batch error rate 7.000000%, alpha 0.279745
# At minibatch 800, batch loss 0.135297, batch error rate 4.000000%, alpha 0.276961
# At minibatch 900, batch loss 0.179030, batch error rate 5.000000%, alpha 0.274206
# At minibatch 1000, batch loss 0.219061, batch error rate 8.000000%, alpha 0.271477
# After epoch 2: valid_err_rate: 0.062800% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.086396, batch error rate 4.000000%, alpha 0.268776
# At minibatch 1200, batch loss 0.143221, batch error rate 7.000000%, alpha 0.266101
# At minibatch 1300, batch loss 0.168669, batch error rate 6.000000%, alpha 0.263453
# At minibatch 1400, batch loss 0.149022, batch error rate 5.000000%, alpha 0.260832
# At minibatch 1500, batch loss 0.057873, batch error rate 2.000000%, alpha 0.258236
# After epoch 3: valid_err_rate: 0.041800% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.098461, batch error rate 4.000000%, alpha 0.255667
# At minibatch 1700, batch loss 0.246364, batch error rate 9.000000%, alpha 0.253123
# At minibatch 1800, batch loss 0.096970, batch error rate 4.000000%, alpha 0.250604
# At minibatch 1900, batch loss 0.103979, batch error rate 3.000000%, alpha 0.248110
# At minibatch 2000, batch loss 0.089745, batch error rate 4.000000%, alpha 0.245641
# After epoch 4: valid_err_rate: 0.033900% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.064068, batch error rate 3.000000%, alpha 0.243197
# At minibatch 2200, batch loss 0.092181, batch error rate 3.000000%, alpha 0.240777
# At minibatch 2300, batch loss 0.177435, batch error rate 7.000000%, alpha 0.238381
# At minibatch 2400, batch loss 0.127451, batch error rate 3.000000%, alpha 0.236009
# At minibatch 2500, batch loss 0.154550, batch error rate 4.000000%, alpha 0.233661
# After epoch 5: valid_err_rate: 0.028600% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.129987, batch error rate 3.000000%, alpha 0.231336
# At minibatch 2700, batch loss 0.141156, batch error rate 6.000000%, alpha 0.229034
# At minibatch 2800, batch loss 0.053795, batch error rate 2.000000%, alpha 0.226755
# At minibatch 2900, batch loss 0.094065, batch error rate 3.000000%, alpha 0.224498
# At minibatch 3000, batch loss 0.057388, batch error rate 2.000000%, alpha 0.222264
# After epoch 6: valid_err_rate: 0.028500% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.225952, batch error rate 5.000000%, alpha 0.220053
# At minibatch 3200, batch loss 0.081770, batch error rate 2.000000%, alpha 0.217863
# At minibatch 3300, batch loss 0.057617, batch error rate 2.000000%, alpha 0.215695
# At minibatch 3400, batch loss 0.107171, batch error rate 3.000000%, alpha 0.213549
# At minibatch 3500, batch loss 0.052248, batch error rate 2.000000%, alpha 0.211424
# After epoch 7: valid_err_rate: 0.024200% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.058750, batch error rate 2.000000%, alpha 0.209320
# At minibatch 3700, batch loss 0.091015, batch error rate 2.000000%, alpha 0.207237
# At minibatch 3800, batch loss 0.125880, batch error rate 6.000000%, alpha 0.205175
# At minibatch 3900, batch loss 0.020019, batch error rate 0.000000%, alpha 0.203133
# At minibatch 4000, batch loss 0.020777, batch error rate 0.000000%, alpha 0.201112
# After epoch 8: valid_err_rate: 0.024200% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.078645, batch error rate 3.000000%, alpha 0.199111
# At minibatch 4200, batch loss 0.111483, batch error rate 3.000000%, alpha 0.197130
# At minibatch 4300, batch loss 0.054793, batch error rate 2.000000%, alpha 0.195168
# At minibatch 4400, batch loss 0.074873, batch error rate 2.000000%, alpha 0.193226
# At minibatch 4500, batch loss 0.073676, batch error rate 2.000000%, alpha 0.191303
# After epoch 9: valid_err_rate: 0.021500% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.042895, batch error rate 2.000000%, alpha 0.189400
# At minibatch 4700, batch loss 0.059430, batch error rate 3.000000%, alpha 0.187515
# At minibatch 4800, batch loss 0.049837, batch error rate 2.000000%, alpha 0.185649
# At minibatch 4900, batch loss 0.084476, batch error rate 3.000000%, alpha 0.183802
# At minibatch 5000, batch loss 0.064320, batch error rate 4.000000%, alpha 0.181973
# After epoch 10: valid_err_rate: 0.021500% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.020646, batch error rate 1.000000%, alpha 0.180162
# At minibatch 5200, batch loss 0.032080, batch error rate 1.000000%, alpha 0.178369
# At minibatch 5300, batch loss 0.060845, batch error rate 2.000000%, alpha 0.176594
# At minibatch 5400, batch loss 0.047645, batch error rate 1.000000%, alpha 0.174837
# At minibatch 5500, batch loss 0.053664, batch error rate 2.000000%, alpha 0.173097
# After epoch 11: valid_err_rate: 0.019800% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.037173, batch error rate 1.000000%, alpha 0.171375
# At minibatch 5700, batch loss 0.025318, batch error rate 0.000000%, alpha 0.169670
# At minibatch 5800, batch loss 0.078659, batch error rate 3.000000%, alpha 0.167981
# At minibatch 5900, batch loss 0.013367, batch error rate 0.000000%, alpha 0.166310
# At minibatch 6000, batch loss 0.056123, batch error rate 1.000000%, alpha 0.164655
# After epoch 12: valid_err_rate: 0.019700% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.056003, batch error rate 4.000000%, alpha 0.163017
# At minibatch 6200, batch loss 0.007144, batch error rate 0.000000%, alpha 0.161394
# At minibatch 6300, batch loss 0.057794, batch error rate 2.000000%, alpha 0.159788
# At minibatch 6400, batch loss 0.034308, batch error rate 1.000000%, alpha 0.158198
# At minibatch 6500, batch loss 0.023124, batch error rate 1.000000%, alpha 0.156624
# After epoch 13: valid_err_rate: 0.021400% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.026986, batch error rate 0.000000%, alpha 0.155066
# At minibatch 6700, batch loss 0.047734, batch error rate 2.000000%, alpha 0.153523
# At minibatch 6800, batch loss 0.041445, batch error rate 1.000000%, alpha 0.151995
# At minibatch 6900, batch loss 0.007760, batch error rate 0.000000%, alpha 0.150483
# At minibatch 7000, batch loss 0.006624, batch error rate 0.000000%, alpha 0.148985
# After epoch 14: valid_err_rate: 0.019400% currently going ot do 22 epochs
# At minibatch 7100, batch loss 0.015329, batch error rate 0.000000%, alpha 0.147503
# At minibatch 7200, batch loss 0.084636, batch error rate 4.000000%, alpha 0.146035
# At minibatch 7300, batch loss 0.020451, batch error rate 1.000000%, alpha 0.144582
# At minibatch 7400, batch loss 0.027702, batch error rate 2.000000%, alpha 0.143143
# At minibatch 7500, batch loss 0.023206, batch error rate 1.000000%, alpha 0.141719
# After epoch 15: valid_err_rate: 0.017800% currently going ot do 23 epochs
# At minibatch 7600, batch loss 0.028101, batch error rate 0.000000%, alpha 0.140309
# At minibatch 7700, batch loss 0.026941, batch error rate 1.000000%, alpha 0.138912
# At minibatch 7800, batch loss 0.030260, batch error rate 1.000000%, alpha 0.137530
# At minibatch 7900, batch loss 0.029416, batch error rate 1.000000%, alpha 0.136162
# At minibatch 8000, batch loss 0.013009, batch error rate 0.000000%, alpha 0.134807
# After epoch 16: valid_err_rate: 0.017700% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.005534, batch error rate 0.000000%, alpha 0.133465
# At minibatch 8200, batch loss 0.034212, batch error rate 1.000000%, alpha 0.132137
# At minibatch 8300, batch loss 0.035942, batch error rate 2.000000%, alpha 0.130822
# At minibatch 8400, batch loss 0.024377, batch error rate 1.000000%, alpha 0.129521
# At minibatch 8500, batch loss 0.034575, batch error rate 2.000000%, alpha 0.128232
# After epoch 17: valid_err_rate: 0.020400% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.019205, batch error rate 0.000000%, alpha 0.126956
# At minibatch 8700, batch loss 0.012422, batch error rate 0.000000%, alpha 0.125693
# At minibatch 8800, batch loss 0.119355, batch error rate 3.000000%, alpha 0.124442
# At minibatch 8900, batch loss 0.064709, batch error rate 1.000000%, alpha 0.123204
# At minibatch 9000, batch loss 0.006834, batch error rate 0.000000%, alpha 0.121978
# After epoch 18: valid_err_rate: 0.016700% currently going ot do 28 epochs
# At minibatch 9100, batch loss 0.026817, batch error rate 1.000000%, alpha 0.120764
# At minibatch 9200, batch loss 0.011356, batch error rate 0.000000%, alpha 0.119562
# At minibatch 9300, batch loss 0.024197, batch error rate 1.000000%, alpha 0.118372
# At minibatch 9400, batch loss 0.073037, batch error rate 2.000000%, alpha 0.117195
# At minibatch 9500, batch loss 0.003498, batch error rate 0.000000%, alpha 0.116028
# After epoch 19: valid_err_rate: 0.017900% currently going ot do 28 epochs
# At minibatch 9600, batch loss 0.003397, batch error rate 0.000000%, alpha 0.114874
# At minibatch 9700, batch loss 0.024078, batch error rate 1.000000%, alpha 0.113731
# At minibatch 9800, batch loss 0.035822, batch error rate 1.000000%, alpha 0.112599
# At minibatch 9900, batch loss 0.008625, batch error rate 0.000000%, alpha 0.111479
# At minibatch 10000, batch loss 0.015704, batch error rate 0.000000%, alpha 0.110369
# After epoch 20: valid_err_rate: 0.017300% currently going ot do 28 epochs
# At minibatch 10100, batch loss 0.036161, batch error rate 1.000000%, alpha 0.109271
# At minibatch 10200, batch loss 0.030640, batch error rate 1.000000%, alpha 0.108184
# At minibatch 10300, batch loss 0.020451, batch error rate 0.000000%, alpha 0.107107
# At minibatch 10400, batch loss 0.002958, batch error rate 0.000000%, alpha 0.106041
# At minibatch 10500, batch loss 0.038138, batch error rate 2.000000%, alpha 0.104986
# After epoch 21: valid_err_rate: 0.016300% currently going ot do 32 epochs
# At minibatch 10600, batch loss 0.010740, batch error rate 0.000000%, alpha 0.103942
# At minibatch 10700, batch loss 0.004043, batch error rate 0.000000%, alpha 0.102907
# At minibatch 10800, batch loss 0.012743, batch error rate 0.000000%, alpha 0.101883
# At minibatch 10900, batch loss 0.063401, batch error rate 2.000000%, alpha 0.100870
# At minibatch 11000, batch loss 0.004466, batch error rate 0.000000%, alpha 0.099866
# After epoch 22: valid_err_rate: 0.016800% currently going ot do 32 epochs
# At minibatch 11100, batch loss 0.011305, batch error rate 0.000000%, alpha 0.098872
# At minibatch 11200, batch loss 0.003422, batch error rate 0.000000%, alpha 0.097888
# At minibatch 11300, batch loss 0.008096, batch error rate 0.000000%, alpha 0.096914
# At minibatch 11400, batch loss 0.018643, batch error rate 0.000000%, alpha 0.095950
# At minibatch 11500, batch loss 0.066580, batch error rate 2.000000%, alpha 0.094995
# After epoch 23: valid_err_rate: 0.016600% currently going ot do 32 epochs
# At minibatch 11600, batch loss 0.011796, batch error rate 0.000000%, alpha 0.094050
# At minibatch 11700, batch loss 0.025949, batch error rate 1.000000%, alpha 0.093114
# At minibatch 11800, batch loss 0.005554, batch error rate 0.000000%, alpha 0.092187
# At minibatch 11900, batch loss 0.022774, batch error rate 1.000000%, alpha 0.091270
# At minibatch 12000, batch loss 0.003170, batch error rate 0.000000%, alpha 0.090362
# After epoch 24: valid_err_rate: 0.016100% currently going ot do 37 epochs
# At minibatch 12100, batch loss 0.012615, batch error rate 1.000000%, alpha 0.089463
# At minibatch 12200, batch loss 0.018903, batch error rate 1.000000%, alpha 0.088573
# At minibatch 12300, batch loss 0.013427, batch error rate 1.000000%, alpha 0.087691
# At minibatch 12400, batch loss 0.007453, batch error rate 0.000000%, alpha 0.086819
# At minibatch 12500, batch loss 0.010329, batch error rate 0.000000%, alpha 0.085955
# After epoch 25: valid_err_rate: 0.016100% currently going ot do 37 epochs
# At minibatch 12600, batch loss 0.007544, batch error rate 0.000000%, alpha 0.085099
# At minibatch 12700, batch loss 0.002120, batch error rate 0.000000%, alpha 0.084253
# At minibatch 12800, batch loss 0.035545, batch error rate 1.000000%, alpha 0.083414
# At minibatch 12900, batch loss 0.014883, batch error rate 1.000000%, alpha 0.082584
# At minibatch 13000, batch loss 0.030830, batch error rate 2.000000%, alpha 0.081762
# After epoch 26: valid_err_rate: 0.016000% currently going ot do 40 epochs
# At minibatch 13100, batch loss 0.003859, batch error rate 0.000000%, alpha 0.080949
# At minibatch 13200, batch loss 0.009300, batch error rate 0.000000%, alpha 0.080143
# At minibatch 13300, batch loss 0.007115, batch error rate 0.000000%, alpha 0.079346
# At minibatch 13400, batch loss 0.004809, batch error rate 0.000000%, alpha 0.078556
# At minibatch 13500, batch loss 0.071254, batch error rate 2.000000%, alpha 0.077775
# After epoch 27: valid_err_rate: 0.015000% currently going ot do 41 epochs
# At minibatch 13600, batch loss 0.019700, batch error rate 1.000000%, alpha 0.077001
# At minibatch 13700, batch loss 0.013088, batch error rate 1.000000%, alpha 0.076234
# At minibatch 13800, batch loss 0.009479, batch error rate 0.000000%, alpha 0.075476
# At minibatch 13900, batch loss 0.004998, batch error rate 0.000000%, alpha 0.074725
# At minibatch 14000, batch loss 0.006545, batch error rate 0.000000%, alpha 0.073981
# After epoch 28: valid_err_rate: 0.015300% currently going ot do 41 epochs
# At minibatch 14100, batch loss 0.001316, batch error rate 0.000000%, alpha 0.073245
# At minibatch 14200, batch loss 0.050655, batch error rate 3.000000%, alpha 0.072516
# At minibatch 14300, batch loss 0.009108, batch error rate 0.000000%, alpha 0.071795
# At minibatch 14400, batch loss 0.003390, batch error rate 0.000000%, alpha 0.071080
# At minibatch 14500, batch loss 0.013994, batch error rate 0.000000%, alpha 0.070373
# After epoch 29: valid_err_rate: 0.014900% currently going ot do 44 epochs
# At minibatch 14600, batch loss 0.004578, batch error rate 0.000000%, alpha 0.069673
# At minibatch 14700, batch loss 0.037769, batch error rate 1.000000%, alpha 0.068979
# At minibatch 14800, batch loss 0.015584, batch error rate 1.000000%, alpha 0.068293
# At minibatch 14900, batch loss 0.002680, batch error rate 0.000000%, alpha 0.067614
# At minibatch 15000, batch loss 0.003261, batch error rate 0.000000%, alpha 0.066941
# After epoch 30: valid_err_rate: 0.015800% currently going ot do 44 epochs
# At minibatch 15100, batch loss 0.052742, batch error rate 3.000000%, alpha 0.066275
# At minibatch 15200, batch loss 0.011142, batch error rate 1.000000%, alpha 0.065615
# At minibatch 15300, batch loss 0.005761, batch error rate 0.000000%, alpha 0.064962
# At minibatch 15400, batch loss 0.027406, batch error rate 1.000000%, alpha 0.064316
# At minibatch 15500, batch loss 0.024819, batch error rate 2.000000%, alpha 0.063676
# After epoch 31: valid_err_rate: 0.015700% currently going ot do 44 epochs
# At minibatch 15600, batch loss 0.040529, batch error rate 2.000000%, alpha 0.063042
# At minibatch 15700, batch loss 0.008924, batch error rate 0.000000%, alpha 0.062415
# At minibatch 15800, batch loss 0.008573, batch error rate 0.000000%, alpha 0.061794
# At minibatch 15900, batch loss 0.006382, batch error rate 0.000000%, alpha 0.061179
# At minibatch 16000, batch loss 0.006830, batch error rate 0.000000%, alpha 0.060570
# After epoch 32: valid_err_rate: 0.016100% currently going ot do 44 epochs
# At minibatch 16100, batch loss 0.008425, batch error rate 0.000000%, alpha 0.059967
# At minibatch 16200, batch loss 0.004230, batch error rate 0.000000%, alpha 0.059371
# At minibatch 16300, batch loss 0.005980, batch error rate 0.000000%, alpha 0.058780
# At minibatch 16400, batch loss 0.001400, batch error rate 0.000000%, alpha 0.058195
# At minibatch 16500, batch loss 0.004233, batch error rate 0.000000%, alpha 0.057616
# After epoch 33: valid_err_rate: 0.015600% currently going ot do 44 epochs
# At minibatch 16600, batch loss 0.003199, batch error rate 0.000000%, alpha 0.057043
# At minibatch 16700, batch loss 0.012011, batch error rate 0.000000%, alpha 0.056475
# At minibatch 16800, batch loss 0.005270, batch error rate 0.000000%, alpha 0.055913
# At minibatch 16900, batch loss 0.002315, batch error rate 0.000000%, alpha 0.055357
# At minibatch 17000, batch loss 0.008366, batch error rate 0.000000%, alpha 0.054806
# After epoch 34: valid_err_rate: 0.014700% currently going ot do 52 epochs
# At minibatch 17100, batch loss 0.004491, batch error rate 0.000000%, alpha 0.054261
# At minibatch 17200, batch loss 0.003518, batch error rate 0.000000%, alpha 0.053721
# At minibatch 17300, batch loss 0.043855, batch error rate 3.000000%, alpha 0.053186
# At minibatch 17400, batch loss 0.003529, batch error rate 0.000000%, alpha 0.052657
# At minibatch 17500, batch loss 0.006873, batch error rate 0.000000%, alpha 0.052133
# After epoch 35: valid_err_rate: 0.015500% currently going ot do 52 epochs
# At minibatch 17600, batch loss 0.005874, batch error rate 0.000000%, alpha 0.051614
# At minibatch 17700, batch loss 0.008297, batch error rate 0.000000%, alpha 0.051100
# At minibatch 17800, batch loss 0.014796, batch error rate 1.000000%, alpha 0.050592
# At minibatch 17900, batch loss 0.005478, batch error rate 0.000000%, alpha 0.050089
# At minibatch 18000, batch loss 0.018656, batch error rate 1.000000%, alpha 0.049590
# After epoch 36: valid_err_rate: 0.015300% currently going ot do 52 epochs
# At minibatch 18100, batch loss 0.005371, batch error rate 0.000000%, alpha 0.049097
# At minibatch 18200, batch loss 0.004901, batch error rate 0.000000%, alpha 0.048608
# At minibatch 18300, batch loss 0.000877, batch error rate 0.000000%, alpha 0.048124
# At minibatch 18400, batch loss 0.028367, batch error rate 1.000000%, alpha 0.047646
# At minibatch 18500, batch loss 0.004835, batch error rate 0.000000%, alpha 0.047172
# After epoch 37: valid_err_rate: 0.015300% currently going ot do 52 epochs
# At minibatch 18600, batch loss 0.008815, batch error rate 0.000000%, alpha 0.046702
# At minibatch 18700, batch loss 0.008403, batch error rate 0.000000%, alpha 0.046237
# At minibatch 18800, batch loss 0.012413, batch error rate 1.000000%, alpha 0.045777
# At minibatch 18900, batch loss 0.002592, batch error rate 0.000000%, alpha 0.045322
# At minibatch 19000, batch loss 0.004404, batch error rate 0.000000%, alpha 0.044871
# After epoch 38: valid_err_rate: 0.014900% currently going ot do 52 epochs
# At minibatch 19100, batch loss 0.012675, batch error rate 1.000000%, alpha 0.044424
# At minibatch 19200, batch loss 0.001564, batch error rate 0.000000%, alpha 0.043982
# At minibatch 19300, batch loss 0.004898, batch error rate 0.000000%, alpha 0.043545
# At minibatch 19400, batch loss 0.001817, batch error rate 0.000000%, alpha 0.043111
# At minibatch 19500, batch loss 0.014285, batch error rate 1.000000%, alpha 0.042682
# After epoch 39: valid_err_rate: 0.015400% currently going ot do 52 epochs
# At minibatch 19600, batch loss 0.003101, batch error rate 0.000000%, alpha 0.042258
# At minibatch 19700, batch loss 0.018258, batch error rate 1.000000%, alpha 0.041837
# At minibatch 19800, batch loss 0.006232, batch error rate 0.000000%, alpha 0.041421
# At minibatch 19900, batch loss 0.003431, batch error rate 0.000000%, alpha 0.041009
# At minibatch 20000, batch loss 0.004639, batch error rate 0.000000%, alpha 0.040601
# After epoch 40: valid_err_rate: 0.014800% currently going ot do 52 epochs
# At minibatch 20100, batch loss 0.005599, batch error rate 0.000000%, alpha 0.040197
# At minibatch 20200, batch loss 0.004272, batch error rate 0.000000%, alpha 0.039797
# At minibatch 20300, batch loss 0.001497, batch error rate 0.000000%, alpha 0.039401
# At minibatch 20400, batch loss 0.017772, batch error rate 1.000000%, alpha 0.039009
# At minibatch 20500, batch loss 0.021469, batch error rate 1.000000%, alpha 0.038620
# After epoch 41: valid_err_rate: 0.015800% currently going ot do 52 epochs
# At minibatch 20600, batch loss 0.005961, batch error rate 0.000000%, alpha 0.038236
# At minibatch 20700, batch loss 0.003930, batch error rate 0.000000%, alpha 0.037856
# At minibatch 20800, batch loss 0.005723, batch error rate 0.000000%, alpha 0.037479
# At minibatch 20900, batch loss 0.013588, batch error rate 1.000000%, alpha 0.037106
# At minibatch 21000, batch loss 0.044227, batch error rate 2.000000%, alpha 0.036737
# After epoch 42: valid_err_rate: 0.014900% currently going ot do 52 epochs
# At minibatch 21100, batch loss 0.001822, batch error rate 0.000000%, alpha 0.036371
# At minibatch 21200, batch loss 0.019129, batch error rate 1.000000%, alpha 0.036009
# At minibatch 21300, batch loss 0.002066, batch error rate 0.000000%, alpha 0.035651
# At minibatch 21400, batch loss 0.005536, batch error rate 0.000000%, alpha 0.035296
# At minibatch 21500, batch loss 0.001250, batch error rate 0.000000%, alpha 0.034945
# After epoch 43: valid_err_rate: 0.014500% currently going ot do 65 epochs
# At minibatch 21600, batch loss 0.012234, batch error rate 1.000000%, alpha 0.034597
# At minibatch 21700, batch loss 0.003759, batch error rate 0.000000%, alpha 0.034253
# At minibatch 21800, batch loss 0.024458, batch error rate 2.000000%, alpha 0.033912
# At minibatch 21900, batch loss 0.001162, batch error rate 0.000000%, alpha 0.033575
# At minibatch 22000, batch loss 0.012707, batch error rate 0.000000%, alpha 0.033241
# After epoch 44: valid_err_rate: 0.014200% currently going ot do 67 epochs
# At minibatch 22100, batch loss 0.010437, batch error rate 0.000000%, alpha 0.032910
# At minibatch 22200, batch loss 0.015317, batch error rate 1.000000%, alpha 0.032582
# At minibatch 22300, batch loss 0.013263, batch error rate 1.000000%, alpha 0.032258
# At minibatch 22400, batch loss 0.030584, batch error rate 2.000000%, alpha 0.031937
# At minibatch 22500, batch loss 0.000835, batch error rate 0.000000%, alpha 0.031619
# After epoch 45: valid_err_rate: 0.014900% currently going ot do 67 epochs
# At minibatch 22600, batch loss 0.003471, batch error rate 0.000000%, alpha 0.031305
# At minibatch 22700, batch loss 0.013828, batch error rate 1.000000%, alpha 0.030993
# At minibatch 22800, batch loss 0.004330, batch error rate 0.000000%, alpha 0.030685
# At minibatch 22900, batch loss 0.020337, batch error rate 1.000000%, alpha 0.030379
# At minibatch 23000, batch loss 0.003024, batch error rate 0.000000%, alpha 0.030077
# After epoch 46: valid_err_rate: 0.015200% currently going ot do 67 epochs
# At minibatch 23100, batch loss 0.006933, batch error rate 0.000000%, alpha 0.029778
# At minibatch 23200, batch loss 0.005669, batch error rate 0.000000%, alpha 0.029482
# At minibatch 23300, batch loss 0.003423, batch error rate 0.000000%, alpha 0.029188
# At minibatch 23400, batch loss 0.001875, batch error rate 0.000000%, alpha 0.028898
# At minibatch 23500, batch loss 0.002766, batch error rate 0.000000%, alpha 0.028610
# After epoch 47: valid_err_rate: 0.014200% currently going ot do 67 epochs
# At minibatch 23600, batch loss 0.008133, batch error rate 0.000000%, alpha 0.028326
# At minibatch 23700, batch loss 0.015881, batch error rate 1.000000%, alpha 0.028044
# At minibatch 23800, batch loss 0.023167, batch error rate 1.000000%, alpha 0.027765
# At minibatch 23900, batch loss 0.004546, batch error rate 0.000000%, alpha 0.027488
# At minibatch 24000, batch loss 0.005456, batch error rate 0.000000%, alpha 0.027215
# After epoch 48: valid_err_rate: 0.014600% currently going ot do 67 epochs
# At minibatch 24100, batch loss 0.008663, batch error rate 0.000000%, alpha 0.026944
# At minibatch 24200, batch loss 0.001258, batch error rate 0.000000%, alpha 0.026676
# At minibatch 24300, batch loss 0.000836, batch error rate 0.000000%, alpha 0.026410
# At minibatch 24400, batch loss 0.002644, batch error rate 0.000000%, alpha 0.026148
# At minibatch 24500, batch loss 0.005739, batch error rate 0.000000%, alpha 0.025887
# After epoch 49: valid_err_rate: 0.014500% currently going ot do 67 epochs
# At minibatch 24600, batch loss 0.001021, batch error rate 0.000000%, alpha 0.025630
# At minibatch 24700, batch loss 0.004345, batch error rate 0.000000%, alpha 0.025375
# At minibatch 24800, batch loss 0.038191, batch error rate 1.000000%, alpha 0.025122
# At minibatch 24900, batch loss 0.004811, batch error rate 0.000000%, alpha 0.024872
# At minibatch 25000, batch loss 0.001313, batch error rate 0.000000%, alpha 0.024625
# After epoch 50: valid_err_rate: 0.014400% currently going ot do 67 epochs
# At minibatch 25100, batch loss 0.003586, batch error rate 0.000000%, alpha 0.024380
# At minibatch 25200, batch loss 0.001106, batch error rate 0.000000%, alpha 0.024137
# At minibatch 25300, batch loss 0.004883, batch error rate 0.000000%, alpha 0.023897
# At minibatch 25400, batch loss 0.010190, batch error rate 1.000000%, alpha 0.023659
# At minibatch 25500, batch loss 0.002799, batch error rate 0.000000%, alpha 0.023424
# After epoch 51: valid_err_rate: 0.015100% currently going ot do 67 epochs
# At minibatch 25600, batch loss 0.016360, batch error rate 1.000000%, alpha 0.023191
# At minibatch 25700, batch loss 0.001897, batch error rate 0.000000%, alpha 0.022960
# At minibatch 25800, batch loss 0.004626, batch error rate 0.000000%, alpha 0.022732
# At minibatch 25900, batch loss 0.007488, batch error rate 0.000000%, alpha 0.022505
# At minibatch 26000, batch loss 0.000818, batch error rate 0.000000%, alpha 0.022281
# After epoch 52: valid_err_rate: 0.014900% currently going ot do 67 epochs
# At minibatch 26100, batch loss 0.004430, batch error rate 0.000000%, alpha 0.022060
# At minibatch 26200, batch loss 0.003599, batch error rate 0.000000%, alpha 0.021840
# At minibatch 26300, batch loss 0.001661, batch error rate 0.000000%, alpha 0.021623
# At minibatch 26400, batch loss 0.004857, batch error rate 0.000000%, alpha 0.021408
# At minibatch 26500, batch loss 0.001985, batch error rate 0.000000%, alpha 0.021195
# After epoch 53: valid_err_rate: 0.015000% currently going ot do 67 epochs
# At minibatch 26600, batch loss 0.003090, batch error rate 0.000000%, alpha 0.020984
# At minibatch 26700, batch loss 0.010043, batch error rate 0.000000%, alpha 0.020775
# At minibatch 26800, batch loss 0.002487, batch error rate 0.000000%, alpha 0.020568
# At minibatch 26900, batch loss 0.016144, batch error rate 1.000000%, alpha 0.020364
# At minibatch 27000, batch loss 0.000376, batch error rate 0.000000%, alpha 0.020161
# After epoch 54: valid_err_rate: 0.015000% currently going ot do 67 epochs
# At minibatch 27100, batch loss 0.003812, batch error rate 0.000000%, alpha 0.019960
# At minibatch 27200, batch loss 0.000419, batch error rate 0.000000%, alpha 0.019762
# At minibatch 27300, batch loss 0.001147, batch error rate 0.000000%, alpha 0.019565
# At minibatch 27400, batch loss 0.005146, batch error rate 0.000000%, alpha 0.019370
# At minibatch 27500, batch loss 0.013491, batch error rate 1.000000%, alpha 0.019178
# After epoch 55: valid_err_rate: 0.014900% currently going ot do 67 epochs
# At minibatch 27600, batch loss 0.006346, batch error rate 0.000000%, alpha 0.018987
# At minibatch 27700, batch loss 0.004761, batch error rate 0.000000%, alpha 0.018798
# At minibatch 27800, batch loss 0.003401, batch error rate 0.000000%, alpha 0.018611
# At minibatch 27900, batch loss 0.014247, batch error rate 1.000000%, alpha 0.018426
# At minibatch 28000, batch loss 0.023016, batch error rate 1.000000%, alpha 0.018242
# After epoch 56: valid_err_rate: 0.014800% currently going ot do 67 epochs
# At minibatch 28100, batch loss 0.008562, batch error rate 0.000000%, alpha 0.018061
# At minibatch 28200, batch loss 0.005254, batch error rate 0.000000%, alpha 0.017881
# At minibatch 28300, batch loss 0.003860, batch error rate 0.000000%, alpha 0.017703
# At minibatch 28400, batch loss 0.001106, batch error rate 0.000000%, alpha 0.017527
# At minibatch 28500, batch loss 0.003133, batch error rate 0.000000%, alpha 0.017353
# After epoch 57: valid_err_rate: 0.014800% currently going ot do 67 epochs
# At minibatch 28600, batch loss 0.001914, batch error rate 0.000000%, alpha 0.017180
# At minibatch 28700, batch loss 0.007316, batch error rate 0.000000%, alpha 0.017009
# At minibatch 28800, batch loss 0.006963, batch error rate 0.000000%, alpha 0.016840
# At minibatch 28900, batch loss 0.003946, batch error rate 0.000000%, alpha 0.016672
# At minibatch 29000, batch loss 0.008000, batch error rate 0.000000%, alpha 0.016506
# After epoch 58: valid_err_rate: 0.014900% currently going ot do 67 epochs
# At minibatch 29100, batch loss 0.003100, batch error rate 0.000000%, alpha 0.016342
# At minibatch 29200, batch loss 0.005085, batch error rate 0.000000%, alpha 0.016179
# At minibatch 29300, batch loss 0.006037, batch error rate 0.000000%, alpha 0.016018
# At minibatch 29400, batch loss 0.001034, batch error rate 0.000000%, alpha 0.015859
# At minibatch 29500, batch loss 0.005975, batch error rate 0.000000%, alpha 0.015701
# After epoch 59: valid_err_rate: 0.014400% currently going ot do 67 epochs
# At minibatch 29600, batch loss 0.002818, batch error rate 0.000000%, alpha 0.015545
# At minibatch 29700, batch loss 0.034395, batch error rate 2.000000%, alpha 0.015390
# At minibatch 29800, batch loss 0.013360, batch error rate 0.000000%, alpha 0.015237
# At minibatch 29900, batch loss 0.002909, batch error rate 0.000000%, alpha 0.015085
# At minibatch 30000, batch loss 0.000439, batch error rate 0.000000%, alpha 0.014935
# After epoch 60: valid_err_rate: 0.015100% currently going ot do 67 epochs
# At minibatch 30100, batch loss 0.004732, batch error rate 0.000000%, alpha 0.014787
# At minibatch 30200, batch loss 0.027323, batch error rate 2.000000%, alpha 0.014640
# At minibatch 30300, batch loss 0.002566, batch error rate 0.000000%, alpha 0.014494
# At minibatch 30400, batch loss 0.000626, batch error rate 0.000000%, alpha 0.014350
# At minibatch 30500, batch loss 0.002257, batch error rate 0.000000%, alpha 0.014207
# After epoch 61: valid_err_rate: 0.014900% currently going ot do 67 epochs
# At minibatch 30600, batch loss 0.007343, batch error rate 0.000000%, alpha 0.014066
# At minibatch 30700, batch loss 0.000891, batch error rate 0.000000%, alpha 0.013926
# At minibatch 30800, batch loss 0.001954, batch error rate 0.000000%, alpha 0.013787
# At minibatch 30900, batch loss 0.001265, batch error rate 0.000000%, alpha 0.013650
# At minibatch 31000, batch loss 0.000543, batch error rate 0.000000%, alpha 0.013514
# After epoch 62: valid_err_rate: 0.014700% currently going ot do 67 epochs
# At minibatch 31100, batch loss 0.008085, batch error rate 0.000000%, alpha 0.013380
# At minibatch 31200, batch loss 0.017443, batch error rate 0.000000%, alpha 0.013246
# At minibatch 31300, batch loss 0.001412, batch error rate 0.000000%, alpha 0.013115
# At minibatch 31400, batch loss 0.022884, batch error rate 1.000000%, alpha 0.012984
# At minibatch 31500, batch loss 0.000850, batch error rate 0.000000%, alpha 0.012855
# After epoch 63: valid_err_rate: 0.014500% currently going ot do 67 epochs
# At minibatch 31600, batch loss 0.000251, batch error rate 0.000000%, alpha 0.012727
# At minibatch 31700, batch loss 0.007113, batch error rate 0.000000%, alpha 0.012600
# At minibatch 31800, batch loss 0.003226, batch error rate 0.000000%, alpha 0.012475
# At minibatch 31900, batch loss 0.004518, batch error rate 0.000000%, alpha 0.012351
# At minibatch 32000, batch loss 0.002989, batch error rate 0.000000%, alpha 0.012228
# After epoch 64: valid_err_rate: 0.014100% currently going ot do 97 epochs
# At minibatch 32100, batch loss 0.001513, batch error rate 0.000000%, alpha 0.012106
# At minibatch 32200, batch loss 0.004985, batch error rate 0.000000%, alpha 0.011986
# At minibatch 32300, batch loss 0.000798, batch error rate 0.000000%, alpha 0.011867
# At minibatch 32400, batch loss 0.006659, batch error rate 0.000000%, alpha 0.011748
# At minibatch 32500, batch loss 0.001289, batch error rate 0.000000%, alpha 0.011632
# After epoch 65: valid_err_rate: 0.014400% currently going ot do 97 epochs
# At minibatch 32600, batch loss 0.014236, batch error rate 0.000000%, alpha 0.011516
# At minibatch 32700, batch loss 0.004403, batch error rate 0.000000%, alpha 0.011401
# At minibatch 32800, batch loss 0.000821, batch error rate 0.000000%, alpha 0.011288
# At minibatch 32900, batch loss 0.002494, batch error rate 0.000000%, alpha 0.011175
# At minibatch 33000, batch loss 0.001873, batch error rate 0.000000%, alpha 0.011064
# After epoch 66: valid_err_rate: 0.014500% currently going ot do 97 epochs
# At minibatch 33100, batch loss 0.001317, batch error rate 0.000000%, alpha 0.010954
# At minibatch 33200, batch loss 0.002550, batch error rate 0.000000%, alpha 0.010845
# At minibatch 33300, batch loss 0.001239, batch error rate 0.000000%, alpha 0.010737
# At minibatch 33400, batch loss 0.000994, batch error rate 0.000000%, alpha 0.010630
# At minibatch 33500, batch loss 0.000555, batch error rate 0.000000%, alpha 0.010525
# After epoch 67: valid_err_rate: 0.014500% currently going ot do 97 epochs
# At minibatch 33600, batch loss 0.007963, batch error rate 0.000000%, alpha 0.010420
# At minibatch 33700, batch loss 0.003736, batch error rate 0.000000%, alpha 0.010316
# At minibatch 33800, batch loss 0.003851, batch error rate 0.000000%, alpha 0.010214
# At minibatch 33900, batch loss 0.010042, batch error rate 0.000000%, alpha 0.010112
# At minibatch 34000, batch loss 0.001763, batch error rate 0.000000%, alpha 0.010011
# After epoch 68: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 34100, batch loss 0.032139, batch error rate 1.000000%, alpha 0.009912
# At minibatch 34200, batch loss 0.006107, batch error rate 0.000000%, alpha 0.009813
# At minibatch 34300, batch loss 0.007335, batch error rate 0.000000%, alpha 0.009715
# At minibatch 34400, batch loss 0.020998, batch error rate 1.000000%, alpha 0.009619
# At minibatch 34500, batch loss 0.001471, batch error rate 0.000000%, alpha 0.009523
# After epoch 69: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 34600, batch loss 0.001366, batch error rate 0.000000%, alpha 0.009428
# At minibatch 34700, batch loss 0.060012, batch error rate 1.000000%, alpha 0.009334
# At minibatch 34800, batch loss 0.025323, batch error rate 1.000000%, alpha 0.009242
# At minibatch 34900, batch loss 0.000813, batch error rate 0.000000%, alpha 0.009150
# At minibatch 35000, batch loss 0.002144, batch error rate 0.000000%, alpha 0.009059
# After epoch 70: valid_err_rate: 0.015200% currently going ot do 97 epochs
# At minibatch 35100, batch loss 0.005741, batch error rate 0.000000%, alpha 0.008968
# At minibatch 35200, batch loss 0.003034, batch error rate 0.000000%, alpha 0.008879
# At minibatch 35300, batch loss 0.003143, batch error rate 0.000000%, alpha 0.008791
# At minibatch 35400, batch loss 0.001655, batch error rate 0.000000%, alpha 0.008703
# At minibatch 35500, batch loss 0.008689, batch error rate 0.000000%, alpha 0.008617
# After epoch 71: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 35600, batch loss 0.005433, batch error rate 0.000000%, alpha 0.008531
# At minibatch 35700, batch loss 0.011573, batch error rate 1.000000%, alpha 0.008446
# At minibatch 35800, batch loss 0.004552, batch error rate 0.000000%, alpha 0.008362
# At minibatch 35900, batch loss 0.017629, batch error rate 1.000000%, alpha 0.008279
# At minibatch 36000, batch loss 0.006543, batch error rate 0.000000%, alpha 0.008196
# After epoch 72: valid_err_rate: 0.015000% currently going ot do 97 epochs
# At minibatch 36100, batch loss 0.005797, batch error rate 0.000000%, alpha 0.008115
# At minibatch 36200, batch loss 0.000567, batch error rate 0.000000%, alpha 0.008034
# At minibatch 36300, batch loss 0.003957, batch error rate 0.000000%, alpha 0.007954
# At minibatch 36400, batch loss 0.037264, batch error rate 2.000000%, alpha 0.007875
# At minibatch 36500, batch loss 0.013328, batch error rate 1.000000%, alpha 0.007797
# After epoch 73: valid_err_rate: 0.014700% currently going ot do 97 epochs
# At minibatch 36600, batch loss 0.015881, batch error rate 1.000000%, alpha 0.007719
# At minibatch 36700, batch loss 0.001607, batch error rate 0.000000%, alpha 0.007642
# At minibatch 36800, batch loss 0.005204, batch error rate 0.000000%, alpha 0.007566
# At minibatch 36900, batch loss 0.001223, batch error rate 0.000000%, alpha 0.007491
# At minibatch 37000, batch loss 0.002978, batch error rate 0.000000%, alpha 0.007416
# After epoch 74: valid_err_rate: 0.014600% currently going ot do 97 epochs
# At minibatch 37100, batch loss 0.002515, batch error rate 0.000000%, alpha 0.007343
# At minibatch 37200, batch loss 0.003167, batch error rate 0.000000%, alpha 0.007270
# At minibatch 37300, batch loss 0.007198, batch error rate 0.000000%, alpha 0.007197
# At minibatch 37400, batch loss 0.001416, batch error rate 0.000000%, alpha 0.007126
# At minibatch 37500, batch loss 0.001150, batch error rate 0.000000%, alpha 0.007055
# After epoch 75: valid_err_rate: 0.014800% currently going ot do 97 epochs
# At minibatch 37600, batch loss 0.004636, batch error rate 0.000000%, alpha 0.006985
# At minibatch 37700, batch loss 0.006560, batch error rate 0.000000%, alpha 0.006915
# At minibatch 37800, batch loss 0.007310, batch error rate 0.000000%, alpha 0.006846
# At minibatch 37900, batch loss 0.002978, batch error rate 0.000000%, alpha 0.006778
# At minibatch 38000, batch loss 0.004571, batch error rate 0.000000%, alpha 0.006711
# After epoch 76: valid_err_rate: 0.015300% currently going ot do 97 epochs
# At minibatch 38100, batch loss 0.003018, batch error rate 0.000000%, alpha 0.006644
# At minibatch 38200, batch loss 0.001574, batch error rate 0.000000%, alpha 0.006578
# At minibatch 38300, batch loss 0.003218, batch error rate 0.000000%, alpha 0.006512
# At minibatch 38400, batch loss 0.000648, batch error rate 0.000000%, alpha 0.006447
# At minibatch 38500, batch loss 0.001878, batch error rate 0.000000%, alpha 0.006383
# After epoch 77: valid_err_rate: 0.015000% currently going ot do 97 epochs
# At minibatch 38600, batch loss 0.017568, batch error rate 1.000000%, alpha 0.006320
# At minibatch 38700, batch loss 0.003571, batch error rate 0.000000%, alpha 0.006257
# At minibatch 38800, batch loss 0.004516, batch error rate 0.000000%, alpha 0.006195
# At minibatch 38900, batch loss 0.003312, batch error rate 0.000000%, alpha 0.006133
# At minibatch 39000, batch loss 0.013096, batch error rate 1.000000%, alpha 0.006072
# After epoch 78: valid_err_rate: 0.015000% currently going ot do 97 epochs
# At minibatch 39100, batch loss 0.001589, batch error rate 0.000000%, alpha 0.006012
# At minibatch 39200, batch loss 0.000948, batch error rate 0.000000%, alpha 0.005952
# At minibatch 39300, batch loss 0.002211, batch error rate 0.000000%, alpha 0.005893
# At minibatch 39400, batch loss 0.000296, batch error rate 0.000000%, alpha 0.005834
# At minibatch 39500, batch loss 0.002147, batch error rate 0.000000%, alpha 0.005776
# After epoch 79: valid_err_rate: 0.015100% currently going ot do 97 epochs
# At minibatch 39600, batch loss 0.002247, batch error rate 0.000000%, alpha 0.005718
# At minibatch 39700, batch loss 0.015534, batch error rate 1.000000%, alpha 0.005661
# At minibatch 39800, batch loss 0.001395, batch error rate 0.000000%, alpha 0.005605
# At minibatch 39900, batch loss 0.000698, batch error rate 0.000000%, alpha 0.005549
# At minibatch 40000, batch loss 0.004694, batch error rate 0.000000%, alpha 0.005494
# After epoch 80: valid_err_rate: 0.015000% currently going ot do 97 epochs
# At minibatch 40100, batch loss 0.001143, batch error rate 0.000000%, alpha 0.005439
# At minibatch 40200, batch loss 0.002087, batch error rate 0.000000%, alpha 0.005385
# At minibatch 40300, batch loss 0.013853, batch error rate 0.000000%, alpha 0.005332
# At minibatch 40400, batch loss 0.008316, batch error rate 0.000000%, alpha 0.005279
# At minibatch 40500, batch loss 0.006037, batch error rate 0.000000%, alpha 0.005226
# After epoch 81: valid_err_rate: 0.014700% currently going ot do 97 epochs
# At minibatch 40600, batch loss 0.000405, batch error rate 0.000000%, alpha 0.005174
# At minibatch 40700, batch loss 0.010413, batch error rate 1.000000%, alpha 0.005123
# At minibatch 40800, batch loss 0.019327, batch error rate 1.000000%, alpha 0.005072
# At minibatch 40900, batch loss 0.011423, batch error rate 1.000000%, alpha 0.005021
# At minibatch 41000, batch loss 0.014575, batch error rate 1.000000%, alpha 0.004971
# After epoch 82: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 41100, batch loss 0.003122, batch error rate 0.000000%, alpha 0.004922
# At minibatch 41200, batch loss 0.001063, batch error rate 0.000000%, alpha 0.004873
# At minibatch 41300, batch loss 0.003484, batch error rate 0.000000%, alpha 0.004824
# At minibatch 41400, batch loss 0.001407, batch error rate 0.000000%, alpha 0.004776
# At minibatch 41500, batch loss 0.020206, batch error rate 1.000000%, alpha 0.004729
# After epoch 83: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 41600, batch loss 0.021927, batch error rate 1.000000%, alpha 0.004682
# At minibatch 41700, batch loss 0.000697, batch error rate 0.000000%, alpha 0.004635
# At minibatch 41800, batch loss 0.001813, batch error rate 0.000000%, alpha 0.004589
# At minibatch 41900, batch loss 0.001953, batch error rate 0.000000%, alpha 0.004543
# At minibatch 42000, batch loss 0.001536, batch error rate 0.000000%, alpha 0.004498
# After epoch 84: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 42100, batch loss 0.006769, batch error rate 0.000000%, alpha 0.004453
# At minibatch 42200, batch loss 0.009109, batch error rate 0.000000%, alpha 0.004409
# At minibatch 42300, batch loss 0.001051, batch error rate 0.000000%, alpha 0.004365
# At minibatch 42400, batch loss 0.005389, batch error rate 0.000000%, alpha 0.004322
# At minibatch 42500, batch loss 0.010829, batch error rate 0.000000%, alpha 0.004279
# After epoch 85: valid_err_rate: 0.014800% currently going ot do 97 epochs
# At minibatch 42600, batch loss 0.001430, batch error rate 0.000000%, alpha 0.004236
# At minibatch 42700, batch loss 0.001529, batch error rate 0.000000%, alpha 0.004194
# At minibatch 42800, batch loss 0.003832, batch error rate 0.000000%, alpha 0.004152
# At minibatch 42900, batch loss 0.002683, batch error rate 0.000000%, alpha 0.004111
# At minibatch 43000, batch loss 0.010254, batch error rate 0.000000%, alpha 0.004070
# After epoch 86: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 43100, batch loss 0.000506, batch error rate 0.000000%, alpha 0.004030
# At minibatch 43200, batch loss 0.001326, batch error rate 0.000000%, alpha 0.003990
# At minibatch 43300, batch loss 0.003362, batch error rate 0.000000%, alpha 0.003950
# At minibatch 43400, batch loss 0.000335, batch error rate 0.000000%, alpha 0.003911
# At minibatch 43500, batch loss 0.006232, batch error rate 0.000000%, alpha 0.003872
# After epoch 87: valid_err_rate: 0.014800% currently going ot do 97 epochs
# At minibatch 43600, batch loss 0.001367, batch error rate 0.000000%, alpha 0.003833
# At minibatch 43700, batch loss 0.000643, batch error rate 0.000000%, alpha 0.003795
# At minibatch 43800, batch loss 0.003091, batch error rate 0.000000%, alpha 0.003757
# At minibatch 43900, batch loss 0.001529, batch error rate 0.000000%, alpha 0.003720
# At minibatch 44000, batch loss 0.001025, batch error rate 0.000000%, alpha 0.003683
# After epoch 88: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 44100, batch loss 0.000538, batch error rate 0.000000%, alpha 0.003646
# At minibatch 44200, batch loss 0.002605, batch error rate 0.000000%, alpha 0.003610
# At minibatch 44300, batch loss 0.010873, batch error rate 0.000000%, alpha 0.003574
# At minibatch 44400, batch loss 0.003180, batch error rate 0.000000%, alpha 0.003538
# At minibatch 44500, batch loss 0.001539, batch error rate 0.000000%, alpha 0.003503
# After epoch 89: valid_err_rate: 0.015200% currently going ot do 97 epochs
# At minibatch 44600, batch loss 0.005421, batch error rate 0.000000%, alpha 0.003468
# At minibatch 44700, batch loss 0.003318, batch error rate 0.000000%, alpha 0.003434
# At minibatch 44800, batch loss 0.001446, batch error rate 0.000000%, alpha 0.003400
# At minibatch 44900, batch loss 0.002003, batch error rate 0.000000%, alpha 0.003366
# At minibatch 45000, batch loss 0.002934, batch error rate 0.000000%, alpha 0.003332
# After epoch 90: valid_err_rate: 0.015000% currently going ot do 97 epochs
# At minibatch 45100, batch loss 0.014013, batch error rate 1.000000%, alpha 0.003299
# At minibatch 45200, batch loss 0.005262, batch error rate 0.000000%, alpha 0.003266
# At minibatch 45300, batch loss 0.006042, batch error rate 0.000000%, alpha 0.003234
# At minibatch 45400, batch loss 0.003298, batch error rate 0.000000%, alpha 0.003202
# At minibatch 45500, batch loss 0.001614, batch error rate 0.000000%, alpha 0.003170
# After epoch 91: valid_err_rate: 0.015200% currently going ot do 97 epochs
# At minibatch 45600, batch loss 0.000611, batch error rate 0.000000%, alpha 0.003138
# At minibatch 45700, batch loss 0.003267, batch error rate 0.000000%, alpha 0.003107
# At minibatch 45800, batch loss 0.000384, batch error rate 0.000000%, alpha 0.003076
# At minibatch 45900, batch loss 0.024127, batch error rate 1.000000%, alpha 0.003045
# At minibatch 46000, batch loss 0.001057, batch error rate 0.000000%, alpha 0.003015
# After epoch 92: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 46100, batch loss 0.001097, batch error rate 0.000000%, alpha 0.002985
# At minibatch 46200, batch loss 0.013687, batch error rate 1.000000%, alpha 0.002955
# At minibatch 46300, batch loss 0.003986, batch error rate 0.000000%, alpha 0.002926
# At minibatch 46400, batch loss 0.011349, batch error rate 1.000000%, alpha 0.002897
# At minibatch 46500, batch loss 0.001324, batch error rate 0.000000%, alpha 0.002868
# After epoch 93: valid_err_rate: 0.015000% currently going ot do 97 epochs
# At minibatch 46600, batch loss 0.004794, batch error rate 0.000000%, alpha 0.002840
# At minibatch 46700, batch loss 0.002312, batch error rate 0.000000%, alpha 0.002811
# At minibatch 46800, batch loss 0.001380, batch error rate 0.000000%, alpha 0.002783
# At minibatch 46900, batch loss 0.002865, batch error rate 0.000000%, alpha 0.002756
# At minibatch 47000, batch loss 0.000544, batch error rate 0.000000%, alpha 0.002728
# After epoch 94: valid_err_rate: 0.014800% currently going ot do 97 epochs
# At minibatch 47100, batch loss 0.001948, batch error rate 0.000000%, alpha 0.002701
# At minibatch 47200, batch loss 0.000642, batch error rate 0.000000%, alpha 0.002674
# At minibatch 47300, batch loss 0.001979, batch error rate 0.000000%, alpha 0.002648
# At minibatch 47400, batch loss 0.027130, batch error rate 1.000000%, alpha 0.002621
# At minibatch 47500, batch loss 0.002742, batch error rate 0.000000%, alpha 0.002595
# After epoch 95: valid_err_rate: 0.014900% currently going ot do 97 epochs
# At minibatch 47600, batch loss 0.000850, batch error rate 0.000000%, alpha 0.002569
# At minibatch 47700, batch loss 0.000241, batch error rate 0.000000%, alpha 0.002544
# At minibatch 47800, batch loss 0.000479, batch error rate 0.000000%, alpha 0.002518
# At minibatch 47900, batch loss 0.001373, batch error rate 0.000000%, alpha 0.002493
# At minibatch 48000, batch loss 0.008846, batch error rate 0.000000%, alpha 0.002469
# After epoch 96: valid_err_rate: 0.015000% currently going ot do 97 epochs
# At minibatch 48100, batch loss 0.001187, batch error rate 0.000000%, alpha 0.002444
# At minibatch 48200, batch loss 0.003131, batch error rate 0.000000%, alpha 0.002420
# At minibatch 48300, batch loss 0.001906, batch error rate 0.000000%, alpha 0.002396
# At minibatch 48400, batch loss 0.002065, batch error rate 0.000000%, alpha 0.002372
# At minibatch 48500, batch loss 0.007638, batch error rate 0.000000%, alpha 0.002348
# After epoch 97: valid_err_rate: 0.015100% currently going ot do 97 epochs
# Test error rate: 0.014400
